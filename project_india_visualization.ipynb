# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
dw_cen=pd.read_csv('district wise population and centroids.csv')
dw_pop=pd.read_csv('district wise population for year 2001 and 2011.csv')
st_cen_2001=pd.read_csv('state wise centroids_2001.csv')
st_cen_2011=pd.read_csv('state wise centroids_2011.csv')
dw_pop_01_11=pd.read_csv('district wise population for year 2001 and 2011.csv')

india_census_hlpca=pd.read_csv('india_census_housing-hlpca-full.csv')
india_dis_2011=pd.read_csv('india-districts-census-2011.csv')
dis_w_cen=pd.read_csv('district wise centroids.csv')

# %%
dw_cen
# Out:
#               State        District   Latitude  Longitude  Population in 2001  \
# 0    Andhra Pradesh       Anantapur  14.312066  77.460158             3640478
# 1    Andhra Pradesh        Chittoor  13.331093  78.927639             3745875
# 2    Andhra Pradesh   East Godavari  16.782718  82.243207             4901420
# 3    Andhra Pradesh          Guntur  15.884926  80.586576             4465144
# 4    Andhra Pradesh         Krishna  16.143873  81.148051             4187841
# ..              ...             ...        ...        ...                 ...
# 426     West Bengal         Kolkata  22.550581  88.352765             4572876
# 427     West Bengal          Maldah  25.080268  88.171917             3290468
# 428     West Bengal     Murshidabad  24.259507  88.168169             5866569
# 429     West Bengal           Nadia  23.564110  88.582930             4604827
# 430     West Bengal  Uttar Dinajpur  26.044619  88.235952             2441794
#
#      Population in 2011
# ...

# %%
dw_pop_01_11
# Out:
#                          State                    District  \
# 0    Andaman & Nicobar Islands                     Nicobar
# 1    Andaman & Nicobar Islands      North & Middle Andaman
# 2    Andaman & Nicobar Islands               South Andaman
# 3               Andhra Pradesh                   Anantapur
# 4               Andhra Pradesh                    Chittoor
# ..                         ...                         ...
# 635                West Bengal           Paschim Medinipur
# 636                West Bengal             Purba Medinipur
# 637                West Bengal          Puruliya (Purulia)
# 638                West Bengal  South Twenty Four Parganas
# 639                West Bengal              Uttar Dinajpur
#
#      Population in 2001  Population in 2011
# 0                 42068               36842
# 1                105613              105597
# 2                208471              238142
# 3               3640478             4081148
# ...

# %%
print(st_cen_2011.head())
print(st_cen_2011.shape)
# Out:
#                  State  Longitude   Latitude
# 0  Andaman and Nicobar  92.889579  11.942373
# 1       Andhra Pradesh  79.916203  16.554124
# 2    Arunachal Pradesh  94.545327  27.725765
# 3                Assam  92.657310  26.321341
# 4                Bihar  85.636774  25.771394
# (35, 3)

# %%
india_dis_2011[india_dis_2011.columns[india_dis_2011.columns.str.startswith('H')]]
# Out:
#      Household_Workers  Hindus  Housholds_with_Electric_Lighting  \
# 0                 7946   37128                             83071
# 1                29102   10110                             90190
# 2                 1020   22882                             17250
# 3                 1222   10341                             15824
# 4                 3930   32604                             62900
# ..                 ...     ...                               ...
# 635                 69   27940                              7150
# 636               1327  152638                             47880
# 637               2560    8681                              9301
# 638                260   81163                             18641
# 639                907  174452                             52479
#
#      Households_with_Internet  Households_with_Computer  Households  \
# 0                         762                      5256      181664
# ...

# %%
dis_w_cen
# Out:
#                    State           District   Latitude  Longitude
# 0    Andaman and Nicobar    Andaman Islands  12.382571  92.822911
# 1    Andaman and Nicobar    Nicobar Islands   7.835291  93.511601
# 2         Andhra Pradesh           Adilabad  19.284514  78.813212
# 3         Andhra Pradesh          Anantapur  14.312066  77.460158
# 4         Andhra Pradesh           Chittoor  13.331093  78.927639
# ..                   ...                ...        ...        ...
# 589          West Bengal  North 24 Parganas  22.062388  88.877940
# 590          West Bengal           Puruliya  23.254192  86.396853
# 591          West Bengal  South 24 Parganas  21.854428  88.445370
# 592          West Bengal     Uttar Dinajpur  26.044619  88.235952
# 593          West Bengal     West Midnapore  22.354897  87.231014
#
# [594 rows x 4 columns]

# %%
final_df=dis_w_cen.merge(india_dis_2011,left_on='District',right_on='District name').drop(columns=['District name'])

# %%
india_dis_2011[india_dis_2011.columns[india_dis_2011.columns.str.startswith('L')]]
print('Fucntion for the columns')
# Out:
# Fucntion for the columns

# %%
def from_b(district):
    if district.startswith('M'):
        return district
    return None

b_str = final_df['District'].apply(from_b)
filtered_df = final_df[b_str.notna()]  # Correct filtering

# %%
final_df['litracy_rate']=round(((final_df['Literate']/final_df['Population'])*100))
final_df
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#          State name  Population     Male   Female  Literate  ...  \
# ...

# %%
final_df=final_df[['State','District','Latitude','Longitude','District code',
          'State name','Population','Male','Female',
          'Literate','litracy_rate','Female_Literate','Male_Literate','Hindus','Muslims',
           'Sikhs','Christians','Jains','Middle_Education','Female_Workers','Male_Workers','Household_Workers',
         'Housholds_with_Electric_Lighting','Households_with_Internet',
         'Households_with_Computer','Primary_Education','Higher_Education','SC','ST']]

# %%
final_df.to_csv('India_data.csv',index=False)

# %%
data=pd.read_csv('India_data.csv')

# %%
print((list(data['State name'].unique())).insert(0,"OVERALL INDIA"))
# Out:
# None

# %%
sorted(data.columns)
# Out:
# ['Christians',
#  'District',
#  'District code',
#  'Female',
#  'Female_Literate',
#  'Female_Workers',
#  'Higher_Education',
#  'Hindus',
#  'Household_Workers',
#  'Households_with_Computer',
#  'Households_with_Internet',
#  'Housholds_with_Electric_Lighting',
#  'Jains',
#  'Latitude',
#  'Literate',
#  'Longitude',
#  'Male',
#  'Male_Literate',
#  'Male_Workers',
#  'Middle_Education',
#  'Muslims',
#  'Population',
#  'Primary_Education',
#  'SC',
#  'ST',
#  'Sikhs',
#  'State',
#  'State name',
#  'litracy_rate']

# %%
col_info=['Population','Male','Female','litracy_rate']

# %%
primary_list=sorted(data.columns[5:])
primary_list
# Out:
# ['Christians',
#  'Female',
#  'Female_Literate',
#  'Female_Workers',
#  'Higher_Education',
#  'Hindus',
#  'Household_Workers',
#  'Households_with_Computer',
#  'Households_with_Internet',
#  'Housholds_with_Electric_Lighting',
#  'Jains',
#  'Literate',
#  'Male',
#  'Male_Literate',
#  'Male_Workers',
#  'Middle_Education',
#  'Muslims',
#  'Population',
#  'Primary_Education',
#  'SC',
#  'ST',
#  'Sikhs',
#  'State name',
#  'litracy_rate']

# %%
state_list=list(data['State name'].unique())
state_list.insert(0,"OVERALL INDIA")
state_list
# Out:
# ['OVERALL INDIA',
#  'ANDHRA PRADESH',
#  'ARUNACHAL PRADESH',
#  'ASSAM',
#  'BIHAR',
#  'MAHARASHTRA',
#  'CHANDIGARH',
#  'CHHATTISGARH',
#  'HIMACHAL PRADESH',
#  'DAMAN AND DIU',
#  'GUJARAT',
#  'GOA',
#  'HARYANA',
#  'UTTAR PRADESH',
#  'JAMMU AND KASHMIR',
#  'JHARKHAND',
#  'KARNATAKA',
#  'KERALA',
#  'MADHYA PRADESH',
#  'MANIPUR',
#  'MEGHALAYA',
#  'MIZORAM',
#  'NAGALAND',
#  'ORISSA',
#  'PONDICHERRY',
#  'PUNJAB',
#  'RAJASTHAN',
#  'NCT OF DELHI',
#  'TAMIL NADU',
#  'TRIPURA',
#  'UTTARAKHAND',
#  'WEST BENGAL']
